# %%
from pycocotools.coco import COCO
import re
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
import random
import json
import os
import shutil
from pathlib import Path
import os.path
import subprocess
import os
import glob
import sys
pylab.rcParams['figure.figsize'] = (8.0, 10.0)

def coco_to_yolo_bb(x1, y1, w, h, image_w, image_h):
    return [((2*x1 + w)/(2*image_w)) , ((2*y1 + h)/(2*image_h)), w/image_w, h/image_h]

def mkdir(dir):
    if not os.path.exists(dir):
        os.makedirs(dir)

def get_cat_data(coco):
    cats = coco.loadCats(coco.getCatIds())
    cat_map = {}
    for i,cat in enumerate(cats):
        cat_map[cat['id']] = i
    catIds = coco.getCatIds()
    return catIds, cat_map

def get_random_img_ids(numImgs,coco):
    imgIds = coco.getImgIds()
    random.shuffle(imgIds)
    imgIds = list(filter(lambda imgId: img_id_has_annotation(imgId, coco), imgIds))
    imgIds = list(filter(lambda imgId: img_id_has_positive_bboxes(imgId,coco), imgIds))
    #add a filter for labels outside frame
    #have a discussion about these images probably
    return imgIds[:numImgs]

def img_id_has_positive_bboxes(imgId,coco):
    annIds = coco.getAnnIds(imgIds=imgId)
    anns = coco.loadAnns(annIds)
    for ann in anns:
        negative_bbox = False 
        for bbox_val in ann['bbox']:
            if bbox_val < 0:
                negative_bbox = True
        if negative_bbox == True:
            return False
    return True

def img_id_has_annotation(imgId,coco):
    annIds = coco.getAnnIds(imgIds=imgId)
    if(len(annIds) > 0):
        return True
    else:
        return False

def write_label_files(numImgs, cat_map, catIds, label_dir1, coco):
    """
    Some images:
    *Do not have annotations.
    *Have negative bboxes
    """
    imgIds = get_random_img_ids(numImgs,coco)

    for imgId in imgIds:
        img = coco.loadImgs(imgId)[0] #If only 1 imgId, len() = 1
        label_dir = Path(label_dir1)
        filename = img['file_name'].split('.')[0] + '.txt'
        with open(label_dir/filename, 'w') as file:
            annIds = coco.getAnnIds(imgIds = imgId, catIds=catIds)
            anns = coco.loadAnns(annIds)
            for i,ann in enumerate(anns):
                x_center, y_center, width, height = coco_to_yolo_bb(*ann['bbox'], img['width'], img['height'])
                file.write(f'{cat_map[ann["category_id"]]} {x_center} {y_center} {width} {height}\n')
    return

def copy_images_to_dataset_dir(src_image_dir, dest_image_dir, image_extension, src_label_dir):
    """
    x number of labels are written to the labels dir by write_label_files(x)
    This function copies the corresponding images into the sibling images dir, completing the dataset folder for YOLO training
    """
    fs = os.listdir(src_label_dir)
    for f in fs:
        if f == '.DS_Store':
            continue
        src = str(src_image_dir/f.split('.')[0]) + image_extension
        dest = str(dest_image_dir/ f.split('.')[0]) + image_extension
        if os.path.isfile(src):
            shutil.copyfile(src, dest)
        else:
            print(f'{src} is not a file')
    return

def dataset_helper(dataset_name):
    #i.e. [n, 2500, t]
    [name, num_imgs, set] = re.split('(\d+)', dataset_name)
    if name == 'c':
        if set == 't':
            print('coco train set not download')
            return
        elif set == 'v':
            src_img_dir = '/usr/src/raw_datasets/coco/val2017'
            annotations_json_file = '/usr/src/raw_datasets/coco/annotations/instances_val2017.json'
    if name == 'n' :
        if set == 't':
            src_img_dir = '/usr/src/raw_datasets/nightowls/nightowls_training'
            annotations_json_file = '/usr/src/raw_datasets/nightowls/nightowls_training.json'
        elif set == 'v':
            src_img_dir = '/usr/src/raw_datasets/nightowls/nightowls_validation'
            annotations_json_file = '/usr/src/raw_datasets/nightowls/nightowls_validation.json'

    dataset_dir = f'/usr/src/datasets/source/n{num_imgs}v'
    label_dir =  f'{dataset_dir}/labels/'
    img_dir = f'{dataset_dir}/images/'

    shutil.rmtree(dataset_dir)
    print(f'{img_dir} removed')

    mkdir(dataset_dir)
    mkdir(label_dir)
    mkdir(img_dir)
    print(f'{dataset_dir} created')
    print(f'{img_dir} created')
    print(f'{label_dir} created')

    return src_img_dir, label_dir, img_dir, annotations_json_file, int(num_imgs)


def produce_dataset(dataset_name):
    src_img_dir, label_dir, img_dir, annotations_json_file, num_imgs = dataset_helper(dataset_name)

    coco=COCO(annotations_json_file)

    catIds, cat_map = get_cat_data(coco)
    write_label_files(num_imgs, cat_map, catIds, label_dir,coco) 
    copy_images_to_dataset_dir(Path(src_img_dir),Path(img_dir), '.jpg', label_dir) #dataset/images

    os.system(f'ls {img_dir} | wc -l ; ls {label_dir} | wc -l')
    return

if __name__ == "__main__":

    #produce_nightowls_training_set(100) #max = 130064
    produce_dataset('n100t') #max = 130064

    #coco=COCO('/usr/src/raw_datasets/nightowls/nightowls_validation.json')
    #produce_nightowls_validation_set(100)
#
#    annotations_json_file = '/Users/azakaria/Documents/yolo datasets/coco/instances_train2017.json'
#    coco=COCO(annotations_json_file)
#    produce_coco_training_set(480)
#
#    annotations_json_file = '/usr/src/raw_datasets/coco/annotations/instances_val2017.json'
#    coco=COCO(annotations_json_file)
#    produce_coco_validation_set(5000)
# Out:
# /usr/src/datasets/source/n100v/images/ removed
# /usr/src/datasets/source/n100v created
# /usr/src/datasets/source/n100v/images/ created
# /usr/src/datasets/source/n100v/labels/ created
# loading annotations into memory...
# Done (t=0.83s)
# creating index...
# index created!
# numImgs 100
# type(numImgs) <class 'int'>
# <class 'list'>
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58280bc2601370013fc7a.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c580e4bc26013700101417.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c580c4bc260130acfd2d62.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5834bbc2601370015e011.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c582cbbc260130ac02258e.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58280bc2601370013fcc4.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c583b1bc2601370016c67f.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5807abc260137e094f502.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c581ecbc26013700129462.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58293bc26013700142a9e.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58098bc260137000f6066.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5829dbc260137001444a8.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58298bc260137001438a0.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5807fbc260137000f2853.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5828abc260137001414be.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c582d6bc260130ac023e59.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c580f3bc260137001035f7.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5802dbc260130acfbc08b.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5826dbc2601370013cf25.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c57fffbc260130acfb7513.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c580e5bc26013700101693.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c581e7bc260137001287f4.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c580e2bc26013700100d6c.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5822dbc2601370013346b.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c580c0bc260130acfd244e.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58298bc26013700143845.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58354bc2601370015f0f6.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c581e8bc2601370012890a.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58284bc26013700140660.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58263bc2601370013b4df.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58211bc260137e098bbd8.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c583aabc2601370016b720.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58341bc2601370015cefe.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5829ebc260137001445de.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58267bc2601370013bf64.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5826bbc2601370013c852.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5833dbc2601370015c6be.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5822abc26013700132d26.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c580ecbc2601370010273e.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c582cbbc260130ac022595.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58138bc260137e096b1b4.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58298bc26013700143804.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c582a4bc26013700145484.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58274bc2601370013e048.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58104bc26013700105f81.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58288bc260137001410e8.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c580ecbc26013700102534.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58284bc26013700140641.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c580ecbc2601370010254a.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c580edbc26013700102997.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58030bc260137e0944907.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c580aabc260130acfcedf7.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58348bc2601370015d969.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5826ebc2601370013cfb1.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58294bc26013700142d2d.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c580e0bc260130acfd715d.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5827fbc2601370013fa40.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58257bc260137001397c8.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58259bc26013700139d1d.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58352bc2601370015ed00.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c582d6bc260130ac0240ae.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58090bc260137000f51d6.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58350bc2601370015e9fe.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c580ecbc2601370010252e.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58353bc2601370015ef89.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58291bc26013700142688.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58264bc2601370013b8ca.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5822cbc26013700133123.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5828ebc26013700141f37.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5813dbc260137e096bfb1.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5822cbc2601370013300c.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58341bc2601370015cd9e.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58275bc2601370013e2a1.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c580d5bc260130acfd5862.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5828cbc26013700141abb.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5829fbc260137001448a2.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5826dbc2601370013cdd9.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58349bc2601370015db58.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58353bc2601370015ef9e.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c580e9bc26013700101def.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58231bc26013700133cb8.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5834bbc2601370015de93.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c57ff6bc2601364077abce.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c57ff6bc2601364077ac47.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5834abc2601370015dc92.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5829fbc26013700144932.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c580acbc260130acfcf1f0.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58231bc26013700133ca4.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c582cbbc260130ac02256e.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5822dbc26013700133443.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5829ebc260137001445ea.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5809abc260137000f646f.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58215bc260137e098c637.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58088bc260137000f3e79.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c582cabc2601370014ae5a.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5822abc26013700132d14.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c580f7bc26013700103efd.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c582d6bc260130ac024012.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c58030bc260137e094499e.jpg is not a file
# /usr/src/raw_datasets/nightowls/nightowls_training/58c5833dbc2601370015c6ee.jpg is not a file
# 0
# 100

# %%
catIds, cat_map = get_cat_data()
#print(catIds)
#print(cat_map)

def confirm_files_origin(dir0, dir1):
    #confirm files in dir0 come from dir1
    dir1_images = os.listdir(dir1)
    dir0_images = os.listdir(dir0)
    for f in dir1_images:
        if f not in dir0_images:
            print(f'{f} not in {dir0_images}')
            return 
    print("All image files originate from the correct source dataset")
    print("Note: label files are derived from annotations.json")
    return

#confirm_files_origin('/usr/src/raw_datasets/nightowls/nightowls_validation','/usr/src/datasets/source/n100v/images')

#def test_get_random_img_ids():
    #for v in get_random_img_ids(100):
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 catIds, cat_map = get_cat_data()
#       2 #print(catIds)
#       3 #print(cat_map)
#       5 def confirm_files_origin(dir0, dir1):
#       6     #confirm files in dir0 come from dir1
#
# TypeError: get_cat_data() missing 1 required positional argument: 'coco'
