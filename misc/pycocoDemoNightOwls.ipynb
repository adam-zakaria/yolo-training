# %%
# %matplotlib inline
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (8.0, 10.0)

# %%
#/Users/azakaria/Downloads/nightowls_validation.json
dataDir='/Users/azakaria/Downloads'
dataFile='nightowls_validation'
annFile=f'{dataDir}/{dataFile}.json'

# %%
# initialize COCO api for instance annotations
coco=COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=0.18s)
# creating index...
# index created!

# %%
"""
# display COCO categories and supercategories
cats = coco.loadCats(coco.getCatIds())
nms=[cat['name'] for cat in cats]
print('COCO categories: \n{}\n'.format(' '.join(nms)))

nms = set([cat['supercategory'] for cat in cats])
print(len(nms))
print('COCO supercategories: \n{}'.format(' '.join(nms)))
"""

annIds = coco.getAnnIds()
#print(annIds)
anns = coco.loadAnns(annIds)
nbi = []
for a in anns:
    for b in a['bbox']:
        if b < 0:
            print(a['bbox'])
            nbi.append(a['id'])
            """
            for img in imgIds:
                x = a['id'] in imgIds
                print(x)
            """

            #continue
            #print(a['bbox'])
coco.showAnns(anns, draw_bbox=True)

# %%
# get all images containing given categories, select one at random
#catIds = coco.getCatIds(catNms=['person','dog','skateboard']);
catIds = coco.getCatIds();
#imgIds = coco.getImgIds(catIds=catIds );
#print(catIds)
imgIds = coco.getImgIds(annIds = 7037569);
print(imgIds)
#imgIds = coco.getImgIds(imgIds = [324158])
#img = coco.loadImgs(imgIds[np.random.randint(0,len(imgIds))])[0]
#print(len(imgIds))
#print(img)
#img = coco.loadImgs(imgIds[0])[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/74/8dm4w0616k7f9j5g46qxjmlm0000gn/T/ipykernel_27996/718967830.py in <module>
#       4 #imgIds = coco.getImgIds(catIds=catIds );
#       5 #print(catIds)
# ----> 6 imgIds = coco.getImgIds(annIds = 7037569);
#       7 print(imgIds)
#       8 #imgIds = coco.getImgIds(imgIds = [324158])
#
# TypeError: getImgIds() got an unexpected keyword argument 'annIds'

# %%
# load and display image
# I = io.imread('%s/images/%s/%s'%(dataDir,dataType,img['file_name']))
# use url to load image
imgPath = f'/Users/azakaria/Downloads/nightowls_validation/{img["file_name"]}'
I = io.imread(imgPath)
plt.axis('off')
plt.imshow(I)
plt.show()

# %%
#annIds = coco.getAnnIds(imgIds=img['id'], iscrowd=None)
#annIds = coco.getAnnIds(imgIds=img['id'])
annIds = coco.getAnnIds()
print(img['id'] in annIds)
print(annIds)

# %%
# load and display instance annotations
plt.imshow(I); plt.axis('off')
#print(img)
#annIds = coco.getAnnIds(imgIds=img['id'], catIds=catIds, iscrowd=None)
#annIds = coco.getAnnIds(imgIds=img['id'], iscrowd=None)
#annIds = coco.getAnnIds(imgIds=img['id'])
# Out:
# [-1, 204, 66, 142]
# [-27, 200, 70, 149]
# [-56, 195, 74, 157]
# [-80, 187, 68, 167]
# [-80, 187, 42, 167]
# [-17, 184, 76, 190]
# [-52, 176, 77, 204]
# [-80, 172, 73, 217]
# [-80, 172, 29, 207]
# [-12, 202, 60, 151]
# [-28, 199, 63, 154]
# [-51, 190, 69, 168]
# [-73, 186, 71, 175]
# [-80, 186, 56, 180]
# [-80, 186, 27, 180]
# [-7, 219, 44, 119]
# [-27, 214, 43, 129]
# [-51, 211, 63, 128]
# [-66, 209, 64, 130]
# [-80, 206, 63, 134]
# [-80, 206, 51, 134]
# [-80, 206, 29, 141]
# [-16, 205, 66, 163]
# [-57, 200, 74, 176]
# [-18, 194, 64, 210]
# [-78, 196, 78, 185]
# [-48, 183, 52, 51]
# [-80, 197, 27, 101]
# [-3, 195, 45, 129]
# [-20, 194, 50, 132]
# [-38, 192, 51, 135]
# [-57, 190, 53, 138]
# [-76, 189, 56, 145]
# [-2, 189, 52, 118]
# [-14, 187, 53, 119]
# [-19, 185, 48, 124]
# [-41, 182, 54, 127]
# [-63, 179, 64, 130]
# [-73, 176, 62, 133]
# [-80, 172, 58, 142]
# [-80, 173, 40, 142]
# [-80, 172, 23, 142]
# [-6, 178, 64, 137]
# [-26, 176, 66, 139]
# [-51, 171, 76, 152]
# [-73, 171, 74, 151]
# [-80, 168, 56, 159]
# [-24, 160, 62, 160]
# [-80, 160, 23, 176]
# [-4, 174, 98, 252]
# [-40, 166, 109, 271]
# [-78, 167, 108, 280]
# [-80, 167, 86, 288]
# [-80, 162, 55, 291]
# [-3, 171, 55, 146]
# [-18, 169, 56, 144]
# [-39, 167, 58, 156]
# [-55, 165, 58, 158]
# [-75, 165, 58, 163]
# [-80, 162, 40, 167]
# [-4, 210, 39, 105]
# [-37, 193, 51, 137]
# [-37, 201, 51, 129]
# [-37, 204, 49, 123]
# [-11, 185, 56, 151]
# [-82, 190, 53, 146]
# [-33, 182, 60, 156]
# [-51, 183, 56, 150]
# [-75, 180, 58, 155]
# [-80, 180, 42, 155]
# [-80, 191, 39, 139]
# [-32, 230, 41, 91]
# [-80, 224, 42, 104]
# [-80, 221, 21, 104]
# [-6, 196, 51, 132]
# [-21, 195, 60, 139]
# [-40, 192, 59, 148]
# [-59, 193, 70, 151]
# [-7, 204, 48, 108]
# [-73, 190, 68, 151]
# [-19, 204, 43, 107]
# [-80, 188, 58, 157]
# [-34, 201, 45, 113]
# [-80, 183, 44, 166]
# [-50, 198, 45, 117]
# [-67, 193, 46, 102]
# [-80, 189, 46, 108]
# [-80, 193, 28, 105]
# [-10, 191, 54, 134]
# [-24, 190, 56, 138]
# [-39, 188, 60, 146]
# [-52, 190, 60, 148]
# [-5, 180, 54, 158]
# [-68, 187, 64, 152]
# [-18, 180, 55, 163]
# [-80, 190, 62, 153]
# [-30, 177, 53, 167]
# [-80, 187, 41, 156]
# [-49, 172, 58, 175]
# [-80, 187, 22, 156]
# [-68, 169, 60, 183]
# [-80, 169, 57, 187]
# [-80, 170, 44, 187]
# [-80, 169, 22, 187]
# [-6, 185, 31, 94]
# [-19, 183, 40, 110]
# [-27, 182, 34, 95]
# [-31, 192, 34, 90]
# [-46, 182, 34, 89]
# [-57, 180, 35, 91]
# [-62, 179, 35, 91]
# [-74, 173, 38, 101]
# [-84, 170, 39, 104]
# [-94, 170, 38, 103]
# [-32, 198, 53, 117]
# [-43, 196, 58, 121]
# [-72, 198, 59, 131]
# [-80, 200, 54, 132]
# [-18, 224, 42, 90]
# [-79, 220, 41, 96]
# [-10, 211, 53, 117]
# [-58, 210, 55, 128]
# [-78, 206, 55, 133]
# [-14, 212, 49, 118]
# [-39, 211, 49, 122]
# [-69, 203, 49, 134]
# [-79, 209, 26, 134]
# [-44, 252, 89, 56]
# [-49, 300, 59, 55]
# [-90, 304, 81, 71]
# [-114, 296, 83, 127]
# [644, -229, 281, 914]
# [581, -141, 400, 985]
# [693, -149, 263, 766]
# [-38, 260, 95, 142]
# [-21, 283, 34, 104]
# [-42, 282, 45, 116]
# [-59, 276, 46, 119]
# [-77, 272, 47, 121]
# [-4, 281, 31, 93]
# [-80, 275, 46, 114]
# [-19, 279, 32, 96]
# [-34, 281, 33, 98]
# [-48, 283, 32, 102]
# [-63, 288, 31, 103]
# [-77, 289, 29, 106]
# [-80, 284, 16, 109]
# [-21, 318, 59, 52]
# [-79, 302, 28, 25]
# [-79, 302, 28, 25]
# [-79, 302, 28, 25]
# [-80, 328, 168, 315]
# [-97, 264, 137, 282]
# [-115, 273, 237, 256]
# [-91, 278, 60, 275]
# [-2, 262, 100, 119]
# [-77, 259, 76, 257]
# [-65, 268, 111, 129]
# [-74, 260, 91, 162]
# [-120, 280, 226, 221]
# [-8, 252, 72, 147]
# [-31, 248, 63, 141]
# [-66, 246, 72, 192]
# [-27, 324, 46, 120]
# [-4, 307, 84, 39]
# [-7, 304, 19, 52]
# [-27, 313, 18, 41]
# [-54, 308, 23, 57]
# [-2, 254, 33, 127]
# [-13, 255, 31, 127]
# [-41, 253, 88, 127]
# [-13, 273, 48, 108]
# [-57, 251, 89, 128]
# [-28, 271, 44, 110]
# [-43, 267, 51, 116]
# [-60, 246, 35, 142]
# [-91, 246, 95, 140]
# [-60, 267, 48, 120]
# [-108, 246, 98, 142]
# [-72, 265, 45, 125]
# [-80, 246, 45, 142]
# [-80, 263, 39, 128]
# [-80, 246, 45, 142]
# [-80, 263, 17, 128]
# [-25, 289, 44, 35]
# [-74, 278, 178, 158]
# [-198, 304, 145, 158]
# [-13, 242, 127, 385]
# [-73, 241, 147, 394]
# [-80, 237, 100, 404]
# [-80, 220, 60, 420]
# [-51, 236, 131, 325]
# [-96, 210, 132, 416]
# [-67, 235, 100, 316]
# [-80, 235, 51, 308]
# [-28, 213, 125, 335]
# [-62, 196, 124, 353]
# [-80, 183, 115, 375]
# [-80, 171, 82, 373]
# [712, -1, 288, 656]
# [-8, 76, 222, 564]
# [-24, 89, 216, 552]
# [-23, 82, 230, 558]
# [-57, 103, 240, 538]
# [-59, 88, 238, 552]
# [-79, 110, 229, 542]
# [-75, 98, 220, 533]
# [-76, 107, 189, 531]
# [-75, 103, 173, 537]
# [-80, 108, 131, 532]
# [-80, 189, 64, 296]
# [-80, 229, 37, 214]
# [-26, 191, 696, 127]
# [-80, 195, 695, 136]
# [-80, 190, 625, 146]
# [-73, 180, 549, 151]
# [-69, 186, 491, 141]
# [-79, 190, 446, 138]
# [-77, 192, 383, 128]
# [-73, 195, 320, 128]
# [-34, 189, 143, 138]
# [-79, 190, 133, 128]
# [-117, 196, 123, 119]
# [-1, 231, 267, 195]
# [-39, 229, 289, 208]
# [-73, 228, 304, 218]
# [-110, 226, 320, 231]
# [-155, 225, 340, 248]
# [-34, 110, 44, 72]
# [-200, 230, 356, 260]
# [-66, 104, 38, 69]
# [-80, 255, 205, 211]
# [-106, 97, 45, 73]
# [-130, 257, 221, 230]
# [-80, 287, 128, 220]
# [-80, 206, 54, 185]
# [-78, 243, 35, 108]
# [-5, 179, 93, 61]
# [-80, 154, 97, 372]
# [-39, 174, 86, 215]
# [-80, 188, 33, 200]
# [-6, 191, 79, 152]
# [-74, 185, 90, 169]
# [-100, 182, 82, 188]
# [-98, 204, 40, 166]
# [-4, 257, 28, 81]
# [-13, 191, 64, 210]
# [-5, 296, 25, 127]
# [-28, 187, 141, 240]
# [-74, 182, 127, 246]
# [-80, 177, 72, 253]
# [-9, 127, 180, 426]
# [-40, 118, 198, 459]
# [-57, 107, 190, 495]
# [-80, 110, 186, 495]
# [-80, 120, 150, 506]
# [-111, 105, 153, 557]
# [-80, 127, 108, 488]
# [-80, 151, 83, 458]
# [-80, 187, 65, 412]
# [-1, 242, 10, 30]
# [-80, 235, 22, 62]
# [-71, 235, 24, 63]
# [-58, 238, 24, 65]
# [-44, 241, 21, 59]
# [-32, 241, 22, 58]
# [-19, 241, 22, 49]
# [-6, 237, 21, 45]
# [-8, 270, 25, 50]
# [-44, 269, 21, 61]
# [-41, 264, 22, 54]
# [-64, 266, 26, 65]
# [-14, 227, 34, 104]
# [-3, 224, 30, 104]
# [-63, 220, 35, 106]
# [-36, 219, 33, 110]
# [-53, 219, 33, 112]
# [-70, 220, 32, 111]
# [-80, 223, 26, 111]
# [-53, 250, 15, 31]
# [-53, 250, 15, 31]
# [-54, 250, 16, 31]
# [-53, 250, 16, 31]
# [-52, 249, 16, 32]
# [-51, 249, 16, 32]
# [-50, 249, 17, 32]
# [-49, 248, 17, 33]
# [-48, 248, 17, 33]
# [-47, 248, 17, 33]
# [-46, 248, 16, 33]
# [-45, 247, 16, 33]
# [-44, 247, 15, 33]
# [-43, 247, 15, 33]
# [-42, 247, 14, 33]
# [-41, 247, 14, 33]
# [-51, 249, 16, 32]
# [-40, 247, 15, 33]
# [-39, 247, 16, 33]
# [-38, 247, 16, 33]
# [-37, 247, 16, 33]
# [-36, 247, 16, 33]
# [-35, 247, 17, 33]
# [-33, 246, 16, 33]
# [-32, 246, 17, 33]
# [-31, 248, 18, 32]
# [-30, 249, 18, 32]
# [-28, 248, 17, 33]
# [-26, 248, 16, 32]
# [-25, 247, 16, 33]
# [-54, 229, 33, 68]
# [-22, 246, 14, 33]
# [-20, 246, 13, 33]
# [-20, 246, 15, 33]
# [-19, 246, 15, 34]
# [-19, 247, 17, 33]
# [-18, 247, 18, 34]
# [-16, 247, 18, 34]
# [-15, 247, 18, 34]
# [-13, 247, 18, 34]
# [-11, 247, 17, 34]
# [-67, 208, 55, 113]
# [-8, 247, 17, 34]
# [-8, 247, 18, 34]
# [-9, 246, 21, 34]
# [-6, 246, 19, 34]
# [-4, 246, 17, 34]
# [-1, 247, 15, 34]
# [-7, 242, 16, 34]
# [-13, 241, 15, 34]
# [-20, 241, 16, 34]
# [-27, 240, 16, 35]
# [-33, 239, 15, 35]
# [-40, 239, 15, 35]
# [-48, 239, 15, 31]
# [-42, 245, 35, 28]
# [-2, 235, 25, 69]
# [-10, 238, 24, 69]
# [-17, 241, 20, 68]
# [-26, 244, 16, 66]
# [-34, 244, 16, 65]
# [-10, 243, 22, 65]
# [-18, 240, 23, 67]
# [-26, 235, 24, 69]
# [-34, 231, 24, 70]
# [-42, 226, 25, 71]
# [-48, 223, 24, 71]
# [-56, 222, 24, 71]
# [-63, 222, 24, 72]
# [-70, 225, 24, 72]
# [-77, 227, 24, 72]
# [-79, 230, 21, 70]
# [-80, 235, 19, 65]
# [-6, 216, 33, 101]
# [-11, 216, 27, 101]
# [-22, 214, 33, 104]
# [-27, 215, 32, 104]
# [-38, 214, 34, 104]
# [-2, 217, 26, 94]
# [-43, 213, 34, 104]
# [-8, 214, 26, 96]
# [-55, 212, 38, 108]
# [-14, 210, 27, 99]
# [-60, 212, 35, 108]
# [-25, 215, 33, 100]
# [-70, 212, 76, 109]
# [-6, 220, 30, 92]
# [-73, 212, 59, 109]
# [-12, 219, 30, 91]
# [-80, 208, 69, 109]
# [-20, 219, 30, 93]
# [-80, 208, 60, 109]
# [-25, 218, 30, 92]
# [-80, 206, 55, 111]
# [-33, 217, 31, 93]
# [-80, 206, 47, 111]
# [-39, 218, 31, 93]
# [-80, 206, 37, 111]
# [-49, 218, 32, 100]
# [-80, 206, 30, 111]
# [-56, 220, 32, 101]
# [-80, 211, 23, 111]
# [-65, 222, 33, 104]
# [-73, 221, 35, 103]
# [-80, 221, 35, 105]
# [-80, 221, 29, 105]
# [-80, 221, 19, 105]
# [-2, 223, 29, 75]
# [-7, 222, 29, 75]
# [-14, 222, 30, 75]
# [-22, 224, 30, 76]
# [-29, 226, 29, 74]
# [-38, 224, 32, 79]
# [-47, 221, 35, 85]
# [-54, 214, 33, 82]
# [-62, 214, 33, 81]
# [-68, 221, 31, 78]
# [-76, 230, 30, 75]
# [-80, 234, 24, 59]
# [-80, 226, 75, 258]
# [-80, 181, 80, 308]
# [-76, 181, 80, 308]
# [-80, 181, 75, 280]
# [-77, 178, 83, 280]
# [-80, 173, 100, 288]
# [-79, 183, 103, 280]
# [-74, 179, 106, 302]
# [-68, 176, 111, 285]
# [-56, 176, 110, 282]
# [-52, 177, 110, 286]
# [-33, 178, 107, 274]
# [-24, 176, 109, 284]
# [-10, 179, 106, 282]
# [-3, 140, 279, 436]
# [-9, 136, 280, 443]
# [-1, 136, 275, 439]
# [-9, 208, 43, 99]
# [-43, 208, 42, 97]
# [-32, 219, 28, 52]
# [-75, 208, 41, 95]
# [-63, 222, 22, 46]
# [-57, 261, 84, 33]
# [-70, 246, 95, 38]
# [-71, 291, 23, 37]
# [-80, 281, 53, 90]
# [-55, 289, 25, 37]
# [-80, 281, 68, 88]
# [-41, 286, 24, 41]
# [-80, 280, 86, 87]
# [-26, 283, 24, 46]
# [-80, 277, 97, 89]
# [-8, 279, 24, 51]
# [-80, 274, 110, 91]
# [-80, 271, 125, 93]
# [-80, 267, 139, 96]
# [-80, 262, 155, 99]
# [-80, 256, 174, 103]
# [-80, 254, 186, 105]
# [-80, 253, 199, 105]
# [-80, 251, 214, 107]
# [-70, 246, 224, 111]
# [-65, 244, 230, 113]
# [-59, 242, 232, 115]
# [-53, 241, 235, 117]
# [-47, 239, 238, 119]
# [-46, 239, 241, 121]
# [-44, 240, 243, 122]
# [-43, 240, 247, 124]
# [-41, 240, 249, 126]
# [-40, 241, 252, 127]
# [-38, 241, 255, 129]
# [-45, 240, 261, 130]
# [-53, 238, 268, 132]
# [-60, 237, 274, 134]
# [-69, 236, 281, 135]
# [-77, 234, 288, 137]
# [-80, 233, 283, 138]
# [-80, 235, 275, 138]
# [-80, 234, 267, 138]
# [-80, 234, 259, 138]
# [-80, 233, 251, 138]
# [-80, 235, 247, 140]
# [-80, 237, 232, 141]
# [-80, 238, 219, 143]
# [-80, 240, 206, 143]
# [-80, 241, 194, 145]
# [-80, 242, 183, 146]
# [-80, 243, 173, 147]
# [-80, 244, 155, 148]
# [-80, 245, 128, 148]
# [-80, 245, 106, 149]
# [-80, 246, 78, 149]
# [-80, 246, 56, 150]
# [-1, 227, 41, 51]
# [-13, 227, 38, 42]
# [-80, 203, 35, 128]
# [-56, 200, 46, 130]
# [-25, 201, 46, 130]
# [-80, 203, 31, 126]
# [-61, 202, 45, 126]
# [-30, 201, 45, 124]
# [-79, 221, 30, 111]
# [-55, 211, 34, 117]
# [-27, 212, 35, 123]
# [-73, 256, 27, 99]
# [-51, 255, 29, 100]
# [-26, 255, 30, 101]
# [-78, 260, 20, 98]
# [-4, 255, 30, 100]
# [-76, 249, 34, 117]
# [-57, 250, 36, 118]
# [-80, 260, 20, 93]
# [-35, 252, 35, 113]
# [-70, 257, 32, 101]
# [-13, 252, 37, 118]
# [-50, 256, 33, 102]
# [-33, 254, 35, 105]
# [-80, 251, 35, 111]
# [-15, 254, 35, 106]
# [-80, 250, 56, 117]
# [-65, 248, 56, 116]
# [-51, 247, 57, 114]
# [-38, 247, 58, 116]
# [-25, 247, 59, 118]
# [-11, 247, 59, 120]
# [-8, 217, 86, 173]
# [-21, 217, 87, 173]
# [-35, 217, 89, 173]
# [-45, 217, 85, 171]
# [-54, 217, 81, 170]
# [-62, 216, 77, 169]
# [-71, 216, 74, 167]
# [-79, 216, 70, 166]
# [-3, 224, 47, 147]
# [-20, 223, 49, 147]
# [-40, 223, 51, 149]
# [-1, 216, 49, 168]
# [-55, 223, 51, 153]
# [-18, 220, 48, 165]
# [-76, 222, 49, 159]
# [-40, 220, 49, 167]
# [-80, 237, 29, 153]
# [-61, 218, 50, 171]
# [-73, 220, 51, 175]
# [-9, 232, 55, 157]
# [-80, 220, 41, 157]
# [-29, 229, 58, 161]
# [-52, 228, 58, 163]
# [-71, 233, 50, 178]
# [-80, 232, 44, 174]
# [-21, 212, 47, 103]
# [-48, 212, 45, 131]
# [-77, 206, 46, 139]
# [-80, 204, 28, 141]
# [-20, 194, 26, 160]
# [-31, 190, 29, 167]
# [-49, 185, 38, 168]
# [-60, 189, 41, 166]
# [-76, 177, 48, 176]
# [-78, 176, 43, 173]
# [-80, 178, 35, 160]
# [-80, 178, 27, 160]
# [-2, 207, 49, 163]
# [-2, 207, 44, 163]
# [-14, 210, 50, 167]
# [-21, 213, 47, 158]
# [-31, 210, 50, 164]
# [-40, 206, 50, 165]
# [-53, 198, 53, 175]
# [-67, 192, 53, 179]
# [-80, 186, 52, 183]
# [-2, 162, 75, 279]
# [-80, 183, 41, 182]
# [-20, 166, 84, 289]
# [-80, 183, 31, 182]
# [-44, 174, 85, 300]
# [-68, 174, 83, 307]
# [-80, 176, 75, 322]
# [-10, 208, 37, 215]
# [-93, 179, 73, 321]
# [-25, 208, 40, 232]
# [-80, 171, 55, 328]
# [-30, 211, 37, 218]
# [-73, 202, 63, 239]
# [-12, 234, 44, 163]
# [-80, 193, 64, 245]
# [-29, 231, 48, 160]
# [-80, 188, 38, 246]
# [-40, 200, 39, 148]
# [-44, 225, 50, 167]
# [-70, 192, 49, 160]
# [-61, 224, 51, 172]
# [-80, 189, 49, 163]
# [-78, 223, 51, 177]
# [-1, 178, 65, 155]
# [-80, 189, 35, 163]
# [-80, 200, 39, 136]
# [-18, 180, 65, 99]
# [-41, 186, 82, 77]
# [-56, 186, 84, 79]
# [-61, 185, 85, 79]
# [-73, 177, 80, 75]
# [-87, 173, 81, 78]
# [-90, 174, 66, 65]
# [-11, 188, 147, 59]
# [-22, 185, 149, 59]
# [-2, 190, 53, 52]
# [-9, 188, 48, 48]
# [-56, 168, 60, 74]
# [-69, 170, 61, 75]
# [-95, 162, 65, 81]
# [-166, 118, 120, 147]
# [-12, 204, 53, 151]
# [-26, 204, 57, 158]
# [-42, 205, 57, 156]
# [-59, 206, 58, 156]
# [-70, 211, 55, 158]
# [-80, 213, 48, 155]
# [-1, 215, 52, 158]
# [-80, 211, 34, 157]
# [-16, 216, 52, 159]
# [-30, 218, 52, 155]
# [-44, 217, 52, 146]
# [-60, 215, 53, 147]
# [-67, 208, 46, 130]
# [-80, 208, 46, 113]
# [-80, 208, 33, 73]
# [-2, 213, 57, 55]
# [-26, 221, 35, 72]
# [-36, 222, 35, 73]
# [-52, 219, 41, 90]
# [-5, 222, 40, 131]
# [-64, 223, 43, 107]
# [-15, 222, 44, 137]
# [-71, 223, 40, 106]
# [-28, 221, 43, 137]
# [-80, 222, 39, 118]
# [-40, 219, 45, 146]
# [-80, 224, 26, 118]
# [-49, 218, 46, 150]
# [-58, 216, 47, 154]
# [-70, 214, 48, 157]
# [-80, 214, 47, 162]
# [-80, 214, 36, 162]
# [-1, 210, 39, 66]
# [-80, 212, 27, 152]
# [-7, 208, 46, 78]
# [-12, 207, 47, 80]
# [-59, 187, 65, 190]
# [-72, 186, 64, 194]
# [-67, 165, 69, 270]
# [-22, 159, 57, 240]
# [-19, 204, 68, 267]
# [-79, 151, 49, 302]
# [-3, 184, 75, 294]
# [-80, 216, 67, 287]
# [-42, 168, 82, 317]
# [-66, 163, 85, 327]
# [-75, 159, 79, 340]
# [-80, 166, 59, 342]
# [-80, 194, 42, 317]
# [-6, 280, 248, 125]
# [-20, 280, 263, 133]
# [-37, 278, 285, 144]
# [-51, 277, 260, 123]
# [-46, 288, 266, 125]
# [-63, 286, 285, 134]
# [-73, 284, 294, 138]
# [-57, 265, 333, 136]
# [-69, 260, 347, 153]
# [-83, 257, 364, 160]
# [-97, 255, 343, 168]
# [-118, 250, 373, 183]
# [-136, 250, 394, 193]
# [-80, 246, 421, 206]
# [-96, 244, 358, 215]
# [-116, 243, 375, 226]
# [-137, 241, 393, 238]
# [-80, 262, 354, 192]
# [-96, 263, 356, 195]
# [-125, 258, 387, 213]
# [-80, 256, 402, 221]
# [-101, 254, 380, 232]
# [-124, 250, 398, 244]
# [-153, 242, 425, 261]
# [-187, 234, 445, 284]
# [-214, 232, 466, 243]
# [-251, 225, 502, 263]
# [-279, 227, 516, 270]
# [-80, 217, 320, 251]
# [-80, 223, 322, 254]
# [-95, 219, 331, 262]
# [-117, 208, 353, 280]
# [-80, 201, 370, 294]
# [-80, 233, 312, 198]
# [-101, 226, 333, 212]
# [-120, 224, 345, 221]
# [-143, 221, 365, 235]
# [-171, 217, 390, 252]
# [-197, 214, 409, 265]
# [-80, 232, 270, 168]
# [-80, 241, 289, 180]
# [-98, 241, 294, 183]
# [-120, 240, 257, 188]
# [-80, 233, 276, 203]
# [-104, 234, 211, 211]
# [-130, 235, 218, 219]
# [-154, 237, 221, 223]
# [-80, 229, 114, 212]
# [-106, 229, 118, 221]
# [-80, 231, 85, 206]
# [-80, 243, 66, 159]
# [-2, 199, 37, 109]
# [-13, 199, 38, 117]
# [-24, 202, 39, 122]
# [-32, 202, 39, 128]
# [-40, 203, 41, 135]
# [-48, 202, 43, 142]
# [-50, 206, 41, 137]
# [-51, 208, 42, 139]
# [-50, 221, 42, 135]
# [-52, 224, 43, 139]
# [-80, 249, 17, 83]
# [-50, 230, 42, 134]
# [-52, 232, 44, 133]
# [-52, 237, 44, 133]
# [-52, 241, 46, 132]
# [-52, 241, 47, 135]
# [-52, 241, 48, 137]
# [-50, 239, 49, 138]
# [-51, 235, 50, 142]
# [-47, 235, 49, 140]
# [-42, 237, 50, 144]
# [-31, 246, 45, 130]
# [-27, 243, 50, 140]
# [-18, 247, 51, 142]
# [-14, 246, 55, 148]
# [-6, 243, 58, 157]
# [-74, 232, 34, 102]
# [-53, 223, 39, 108]
# [-29, 222, 38, 104]
# [-79, 214, 34, 112]
# [-6, 216, 40, 106]
# [-63, 198, 38, 122]
# [-42, 192, 41, 120]
# [-21, 181, 43, 128]
# [-77, 172, 27, 76]
# [-53, 170, 28, 77]
# [-80, 170, 24, 79]
# [-28, 171, 29, 79]
# [-56, 170, 27, 81]
# [-2, 178, 28, 77]
# [-33, 174, 28, 83]
# [-5, 180, 27, 80]
# [-73, 205, 28, 80]
# [-49, 202, 29, 84]
# [-67, 201, 22, 87]
# [-24, 199, 30, 86]
# [-45, 199, 23, 83]
# [-20, 199, 20, 73]
# [-64, 126, 158, 433]
# [-25, 116, 57, 169]
# [-63, 117, 56, 173]
# [-76, 133, 49, 152]
# [-79, 263, 181, 33]
# [-42, 251, 190, 32]
# [-87, 235, 113, 250]
# [-7, 208, 42, 47]
# [-25, 206, 45, 49]
# [-42, 206, 51, 53]
# [-59, 208, 53, 54]
# [-72, 219, 52, 60]
# [-79, 228, 38, 52]
# [-78, 218, 16, 67]
# [-80, 217, 21, 81]
# [-76, 219, 25, 83]
# [-69, 221, 26, 83]
# [-62, 222, 27, 84]
# [-55, 224, 28, 83]
# [-46, 226, 27, 81]
# [-37, 225, 29, 83]
# [-27, 225, 30, 85]
# [-16, 224, 29, 83]
# [-4, 222, 29, 84]
# [-80, 183, 35, 123]
# [-1, 246, 418, 156]
# [-35, 236, 423, 162]
# [-71, 226, 429, 168]
# [-31, 230, 286, 171]
# [-70, 228, 266, 161]
# [-74, 249, 189, 154]
# [-77, 263, 137, 149]
# [-79, 273, 100, 145]
# [-80, 280, 72, 143]
# [-80, 251, 25, 84]
# [-8, 157, 81, 293]
# [-24, 154, 82, 302]
# [-38, 153, 87, 311]
# [-55, 145, 92, 332]
# [-68, 144, 88, 329]
# [-96, 180, 62, 197]
# [-80, 135, 92, 339]
# [-100, 136, 93, 364]
# [-80, 134, 47, 365]
# [-3, 195, 54, 172]
# [-16, 191, 58, 175]
# [-25, 190, 58, 171]
# [-37, 184, 56, 185]
# [-39, 181, 60, 190]
# [-12, 241, 52, 131]
# [-52, 185, 68, 200]
# [-24, 240, 52, 131]
# [-52, 185, 68, 200]
# [-37, 243, 52, 130]
# [-75, 185, 67, 207]
# [-50, 258, 52, 131]
# [-76, 190, 59, 204]
# [-64, 258, 52, 131]
# [-80, 192, 54, 187]
# [-13, 192, 76, 206]
# [-68, 255, 52, 137]
# [-80, 188, 45, 218]
# [-18, 187, 77, 212]
# [-68, 255, 52, 137]
# [-35, 187, 77, 212]
# [-80, 255, 51, 137]
# [-45, 180, 78, 219]
# [-85, 257, 51, 136]
# [-68, 178, 89, 221]
# [-70, 170, 78, 235]
# [-80, 170, 76, 241]
# [-80, 170, 66, 241]
# [-80, 170, 55, 241]
# [-80, 170, 47, 242]
# [-80, 170, 47, 242]
# [-20, 177, 81, 256]
# [-63, 188, 113, 234]
# [-80, 171, 96, 264]
# [-101, 210, 68, 190]
# [-73, 203, 30, 95]
# [-41, 200, 29, 92]
# [-15, 195, 32, 100]
# [-78, 190, 264, 52]
# [-13, 209, 41, 121]
# [-80, 183, 50, 258]
# [-80, 153, 78, 299]
# [-67, 153, 105, 292]
# [-28, 141, 110, 317]
# [-79, 210, 40, 194]
# [-80, 205, 48, 200]
# [-80, 195, 51, 212]
# [-79, 195, 57, 212]
# [-79, 192, 66, 221]
# [-72, 191, 67, 226]
# [-64, 198, 68, 214]
# [-80, 215, 28, 194]
# [-62, 194, 68, 216]
# [-80, 215, 30, 194]
# [-56, 193, 70, 222]
# [-80, 215, 34, 194]
# [-52, 188, 72, 228]
# [-80, 215, 38, 196]
# [-44, 198, 72, 218]
# [-80, 216, 45, 197]
# [-41, 196, 73, 222]
# [-76, 216, 45, 197]
# [-35, 199, 71, 216]
# [-73, 215, 48, 194]
# [-32, 193, 73, 224]
# [-72, 215, 48, 194]
# [-27, 189, 74, 229]
# [-71, 214, 53, 194]
# [-22, 194, 77, 227]
# [-67, 213, 56, 194]
# [-18, 195, 76, 224]
# [-63, 213, 55, 195]
# [-12, 197, 81, 220]
# [-58, 213, 55, 195]
# [-8, 194, 80, 225]
# [-61, 213, 60, 195]
# [-8, 188, 82, 232]
# [-62, 213, 63, 195]
# [-4, 193, 83, 229]
# [-58, 213, 62, 196]
# [-5, 187, 87, 240]
# [-58, 213, 62, 196]
# [-7, 195, 91, 225]
# [-60, 216, 62, 196]
# [-7, 192, 90, 234]
# [-62, 216, 62, 196]
# [-67, 216, 62, 195]
# [-12, 195, 92, 222]
# [-62, 212, 62, 201]
# [-10, 190, 93, 240]
# [-71, 212, 65, 204]
# [-14, 193, 91, 235]
# [-74, 209, 64, 208]
# [-21, 191, 91, 235]
# [-80, 209, 64, 208]
# [-29, 188, 94, 242]
# [-80, 209, 55, 210]
# [-36, 187, 92, 241]
# [-80, 209, 51, 211]
# [-47, 182, 95, 251]
# [-80, 209, 33, 211]
# [-54, 177, 88, 253]
# [-80, 209, 33, 211]
# [-66, 180, 86, 247]
# [-74, 176, 86, 260]
# [-94, 166, 91, 276]
# [-80, 172, 54, 256]
# [-80, 175, 38, 184]
# [-37, 240, 34, 85]
# [-24, 204, 67, 154]
# [-20, 207, 51, 163]
# [-30, 220, 48, 163]
# [-50, 212, 55, 186]
# [-2, 182, 79, 206]
# [-22, 186, 80, 208]
# [-46, 186, 81, 212]
# [-70, 179, 83, 226]
# [-80, 165, 73, 249]
# [-80, 182, 55, 226]
# [-8, 179, 129, 294]
# [-24, 176, 128, 302]
# [-49, 169, 125, 321]
# [-66, 164, 126, 330]
# [-71, 164, 109, 342]
# [-110, 120, 105, 400]
# [-110, 120, 103, 400]
# [-78, 199, 33, 137]
# [-70, 195, 53, 158]
# [-50, 191, 54, 163]
# [-21, 193, 53, 159]
# [-40, 216, 86, 56]
# [-74, 243, 120, 42]
# [-7, 216, 79, 245]
# [-80, 200, 57, 280]
# [-50, 177, 93, 303]
# [-17, 180, 106, 334]
# [-78, 172, 106, 391]
# [-80, 274, 43, 323]
# [-79, 255, 14, 42]
# [-6, 259, 71, 81]
# [-26, 260, 74, 83]
# [-51, 258, 84, 88]
# [-75, 262, 79, 86]
# [-95, 267, 73, 81]
# [-95, 267, 53, 81]
# [-95, 267, 48, 86]
# [-80, 267, 23, 81]
# [-2, 224, 41, 108]
# [-20, 227, 38, 115]
# [-22, 216, 42, 122]
# [-53, 225, 45, 126]
# [-17, 213, 52, 136]
# [-63, 225, 39, 130]
# [-25, 222, 45, 134]
# [-67, 220, 53, 132]
# [-40, 222, 46, 138]
# [-80, 224, 28, 136]
# [-57, 220, 48, 145]
# [-80, 223, 18, 139]
# [-67, 218, 47, 147]
# [-79, 220, 42, 148]
# [-85, 220, 34, 138]
# [-1, 232, 34, 44]
# [-80, 298, 38, 147]
# [941, -3, 37, 77]
# [957, -10, 37, 76]
# [980, -2, 32, 58]
# [-48, 130, 54, 74]
# [-2, 241, 34, 42]
# [-1, 313, 16, 81]
# [-1, 314, 16, 81]
# [-1, 265, 193, 125]
# [-17, 268, 198, 128]
# [-34, 270, 204, 133]
# [-52, 273, 211, 137]
# [-71, 276, 217, 141]
# [-80, 283, 209, 141]
# [-80, 290, 193, 141]
# [-80, 296, 179, 141]
# [-80, 302, 166, 140]
# [-80, 310, 144, 141]
# [-80, 316, 125, 143]
# [-80, 322, 108, 144]
# [-80, 326, 94, 153]
# [-80, 330, 80, 161]
# [-80, 332, 54, 124]
# [-3, 280, 55, 128]
# [-3, 266, 51, 52]
# [-12, 266, 51, 52]
# [-32, 263, 51, 52]
# [-45, 262, 60, 54]
# [-62, 262, 69, 58]
# [-66, 261, 69, 58]
# [-74, 262, 72, 61]
# [-80, 260, 72, 61]
# [-80, 262, 72, 61]
# [-80, 265, 66, 61]
# [-80, 267, 66, 61]
# [-80, 267, 61, 61]
# [-80, 268, 61, 61]
# [-80, 270, 61, 61]
# [-80, 270, 60, 61]
# [-80, 272, 60, 61]
# [-80, 270, 60, 61]
# [-80, 270, 60, 61]
# [-80, 270, 60, 61]
# [-80, 270, 63, 61]
# [-80, 270, 65, 61]
# [-80, 271, 71, 61]
# [-76, 273, 75, 61]
# [-71, 276, 77, 61]
# [-73, 275, 85, 64]
# [-80, 264, 100, 79]
# [-77, 262, 111, 84]
# [-67, 259, 115, 87]
# [-51, 257, 113, 87]
# [-37, 256, 113, 87]
# [-24, 256, 116, 88]
# [-10, 252, 120, 89]
# [-30, 243, 56, 20]
# [-80, 306, 28, 42]
# [-80, 309, 56, 50]
# [-80, 294, 83, 62]
# [-59, 287, 83, 62]
# [-27, 284, 97, 65]
# [-80, 288, 32, 184]
# [-20, 202, 69, 194]
# [-42, 195, 68, 210]
# [-69, 195, 71, 220]
# [-80, 197, 55, 211]
# [-86, 215, 39, 155]
# [-12, 245, 104, 55]
# [-8, 217, 35, 80]
# [-16, 218, 30, 75]
# [-31, 212, 36, 84]
# [-44, 212, 35, 87]
# [-52, 211, 33, 85]
# [-68, 204, 35, 97]
# [-79, 219, 31, 81]
# [-80, 219, 25, 79]
# [-4, 256, 115, 73]
# [-14, 258, 114, 81]
# [-24, 258, 116, 74]
# [-35, 258, 121, 78]
# [-41, 259, 116, 76]
# [-52, 255, 120, 84]
# [-67, 255, 127, 86]
# [-76, 256, 125, 90]
# [-80, 254, 125, 91]
# [-80, 254, 114, 91]
# [-80, 259, 103, 85]
# [-80, 259, 91, 93]
# [-80, 267, 81, 83]
# [-80, 270, 72, 82]
# [-80, 263, 59, 93]
# [-57, 235, 79, 42]
# [-80, 244, 88, 48]
# [-3, 252, 26, 51]
# [-58, 259, 72, 30]
# [-14, 250, 29, 59]
# [-23, 248, 30, 62]
# [-25, 249, 26, 63]
# [-33, 232, 26, 72]
# [-5, 239, 25, 67]
# [-41, 231, 28, 72]
# [-14, 237, 27, 68]
# [-48, 231, 29, 70]
# [-17, 233, 26, 68]
# [-56, 231, 32, 74]
# [-21, 233, 24, 68]
# [-62, 232, 33, 76]
# [-29, 235, 22, 67]
# [-68, 233, 32, 76]
# [-34, 236, 20, 65]
# [-73, 230, 28, 80]
# [-44, 231, 22, 76]
# [-78, 233, 26, 77]
# [-49, 233, 22, 74]
# [-80, 233, 21, 77]
# [-58, 233, 24, 78]
# [-74, 236, 29, 78]
# [-79, 238, 23, 76]
# [-80, 243, 25, 69]
# [-22, 255, 29, 87]
# [-51, 255, 30, 91]
# [-80, 247, 30, 91]
# [-24, 256, 33, 94]
# [-51, 256, 35, 99]
# [-80, 253, 35, 103]
# [-1, 249, 31, 92]
# [-15, 246, 31, 94]
# [-37, 248, 31, 93]
# [-55, 249, 32, 96]
# [-18, 248, 31, 94]
# [-76, 247, 33, 100]
# [-39, 248, 32, 96]
# [-80, 246, 25, 80]
# [-58, 245, 34, 94]
# [-78, 240, 34, 101]
# [-8, 274, 120, 62]
# [-2, 270, 20, 72]
# [-103, 313, 43, 69]
# [-103, 313, 43, 69]
# [-103, 313, 43, 69]
# [-103, 313, 43, 69]
# [-76, 268, 32, 96]
# [-54, 267, 32, 96]
# [-34, 265, 33, 95]
# [-18, 262, 34, 97]
# [-3, 259, 35, 99]
# [-1, 255, 39, 120]
# [-16, 252, 40, 124]
# [-33, 250, 41, 127]
# [-59, 247, 42, 134]
# [-78, 246, 42, 144]
# [-80, 249, 26, 133]
# [-83, 284, 180, 125]
# [-1, 290, 19, 105]
# [-184, 275, 227, 126]
# [-22, 259, 178, 122]
# [-3, 255, 143, 107]
# [-8, 254, 325, 106]
# [-79, 262, 378, 121]
# [-62, 263, 359, 109]
# [-81, 257, 358, 133]
# [-59, 255, 303, 118]
# [-19, 275, 86, 84]
# [-84, 265, 41, 242]
# [-4, 261, 87, 100]
# [-92, 257, 105, 121]
# [-32, 261, 468, 119]
# [-80, 270, 539, 119]
# [-80, 269, 502, 134]
# [-1, 324, 21, 75]
# [-79, 269, 448, 129]
# [-3, 245, 340, 50]
# [-2, 266, 1027, 175]
# [-63, 271, 169, 61]
# [-102, 273, 180, 67]
# [-8, 207, 109, 239]
# [-66, 270, 105, 111]
# [-86, 273, 114, 115]
# [-80, 268, 83, 129]
# [-81, 272, 53, 129]
# [-51, 265, 178, 69]
# [-55, 252, 31, 48]
# [-78, 252, 29, 49]
# [-64, 213, 110, 342]
# [-80, 203, 87, 343]
# [-80, 249, 510, 189]
# [-80, 248, 416, 185]
# [-80, 249, 365, 185]
# [-80, 249, 348, 185]
# [-80, 249, 321, 185]
# [-66, 251, 294, 185]

# %%
# initialize COCO api for person keypoints annotations
annFile = '{}/annotations/person_keypoints_{}.json'.format(dataDir,dataType)
coco_kps=COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=0.26s)
# creating index...
# index created!

# %%
# load and display keypoints annotations
plt.imshow(I); plt.axis('off')
ax = plt.gca()
annIds = coco_kps.getAnnIds(imgIds=img['id'], catIds=catIds, iscrowd=None)
anns = coco_kps.loadAnns(annIds)
coco_kps.showAnns(anns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/74/8dm4w0616k7f9j5g46qxjmlm0000gn/T/ipykernel_27996/1834685713.py in <module>
#       2 plt.imshow(I); plt.axis('off')
#       3 ax = plt.gca()
# ----> 4 annIds = coco_kps.getAnnIds(imgIds=img['id'], catIds=catIds, iscrowd=None)
#       5 anns = coco_kps.loadAnns(annIds)
#       6 print(anns)
#
# NameError: name 'coco_kps' is not defined

# %%
# initialize COCO api for caption annotations
annFile = '{}/annotations/captions_{}.json'.format(dataDir,dataType)
coco_caps=COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=0.13s)
# creating index...
# index created!

# %%
# load and display caption annotations
annIds = coco_caps.getAnnIds(imgIds=img['id']);
anns = coco_caps.loadAnns(annIds)
coco_caps.showAnns(anns)
plt.imshow(I); plt.axis('off'); plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/74/8dm4w0616k7f9j5g46qxjmlm0000gn/T/ipykernel_20474/3601217509.py in <module>
#       1 # load and display caption annotations
# ----> 2 annIds = coco_caps.getAnnIds(imgIds=img['id']);
#       3 anns = coco_caps.loadAnns(annIds)
#       4 coco_caps.showAnns(anns)
#       5 plt.imshow(I); plt.axis('off'); plt.show()
#
# NameError: name 'coco_caps' is not defined
